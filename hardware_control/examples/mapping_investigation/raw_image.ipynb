# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from astropy.io import fits
import matplotlib.animation as animation
import imageio

# %%
path = '/Users/sbry5606/phd/phd-code/drift/'

# Load the data
# data1 = np.loadtxt(path+'frames1/raw/pupil_actuator0_volt_0.3.txt')
# data2 = np.load(path+'frames2/raw/pupil_actuator0_0.5.npz')['arr_0']
# data3 = np.load(path+'frames3/raw/pupil_pokeall_actuator0_volt0.5.npz')['arr_0']
# data4 = np.load(path+'frames4/raw/pupil_ptt_segment0.npz')['arr_0']
# data5 = np.load(path+'frames5/raw/pupil_pist_segment0.npz')['arr_0']
data1 = np.load(path+'vignette`_pupil.npz')['arr_0']
data2 = np.load(path+'pupil_image_02-04-2024v2.npz')['pupil']

# Flip the data vertically
data1_flipped = np.flipud(data1)
data2_flipped = np.flipud(data2)
# data3_flipped = np.flipud(data3)
# data4_flipped = np.flipud(data4)
# data5_flipped = np.flipud(data4)

# Plot the flipped data
plt.imshow(data1_flipped, cmap='afmhot')
plt.show()
plt.imshow(data2_flipped, cmap='afmhot')
plt.show()
# plt.imshow(data3_flipped, cmap='afmhot')
# plt.show()
# plt.imshow(data4_flipped, cmap='afmhot')
# plt.show()
# plt.imshow(data5_flipped, cmap='afmhot')
# plt.show()

# %%
path = '/Users/sbry5606/phd/phd-code/bmc/mapping_investigation/data/'

# Load the data
data1 = np.loadtxt(path+'frames1/raw/image_actuator0_volt_0.3.txt')
data2 = np.load(path+'frames2/raw/image_actuator0_0.5.npz')['arr_0']
data3 = np.load(path+'frames3/raw/image_pokeall_actuator0_volt0.5.npz')['arr_0']
data4 = np.load(path+'frames4/raw/image_ptt_segment0.npz')['arr_0']
data5 = np.load(path+'frames5/raw/image_pist_segment0.npz')['arr_0']

# Flip the data vertically
data1_flipped = np.flipud(data1)
data2_flipped = np.flipud(data2)
data3_flipped = np.flipud(data3)
data4_flipped = np.flipud(data4)
data5_flipped = np.flipud(data4)

# Plot the flipped data
plt.imshow(data1_flipped, cmap='afmhot')
plt.show()
plt.imshow(data2_flipped, cmap='afmhot')
plt.show()
plt.imshow(data3_flipped, cmap='afmhot')
plt.show()
plt.imshow(data4_flipped, cmap='afmhot')
plt.show()
plt.imshow(data5_flipped, cmap='afmhot')
plt.show()
